# %% [markdown]
# <div style=" padding: 40px; text-align: center; color: #8e44ad;text-shadow: 2px 2px 0px #f1c40f; ">
#     <h1 style="font-family: 'Roboto', sans-serif;ext-align: center;  font-size: 72px; margin-top: 0; margin-bottom: 20px;">
#     Statistics
#     </h1>
# </div>

# %% [markdown]
# <div style=" padding: 40px; text-align: center; color: #8e44ad;text-shadow: 2px 2px 0px #f1c40f; ">
#     <h1 style="font-family: 'Roboto', sans-serif;ext-align: center;  font-size: 72px; margin-top: 0; margin-bottom: 20px;">
#     Exercise 4
#     </h1>
# </div>

# %% [markdown]
# ![SNOWFALL](ex4.png)

# %% [markdown]
# <p style="background-color:#4B0082;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">
# Flights
# </p>
#
#
# <br>
#
# <div style="text-align:center;">
# <img  src="air.png">
# </div>
#
#
#
#
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#4B0082;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">
#
#  This dataset contains information about all flights that departed from NYC (e.g. EWR, JFK and LGA) in 2013: 336,776 flights in total. The dataset misses the data related to the cause of delays. If the causes of delays were available in data set than it would be easy to pinpoint the delays, which, can be eliminated or minimised by carriers.
#
#
#
#
#
#
# <div style="align:center">
#
# Dataset Details
#
# year - Year of Flight
#
# month - Month of Flight
#
# day - Day (number of Flight)
#
# dep_time - Departure Time
#
# sched_dep_time - Scheduled Departure Time
#
# dep_delay - Departure Delay (in Minutes)
#
# arr_time - Arrival Time
#
# sched_arr_time - Scheduled Arrival Time
#
# arr_delay - Arrival Delay (in Minutes)
#
# carrier- Carrier Details of Flight
#
# flight - Flight Name
#
# tailnum - Tail number of Flight
#
# origin - Origin of Flight
#
# dest - Destination Airport Name
#
# air_time - Air Time (Time in Air - travel Time ( in minutes) )
#
# distance - Distance (assuming in miles?)
#
# hour - Hour
#
# minute - minute
#
# time_hour - time hour
#
# </div>
#
# </p>

# %% [markdown]
# <hr>
# <a id="1"></a>
# <p style="background-color:#4B0082;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">📚 IMPORTING LIBRARIES</p>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# <p style="background-color:#4B0082;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">📖 LOADING DATA</p>

# %%
df = pd.read_csv('flights.csv')

# %% [markdown]
# <p style="background-color:#4B0082;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">🧐 Data Overview</p>

# %%
rows,cols = df.shape
print("Number of rows: ", rows)
print("Number of columns: ", cols)
# Out:
# Number of rows:  336776
# Number of columns:  21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
# ...

# %%
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
df.tail()
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 336771  336771  2013      9   30       NaN            1455        NaN
# 336772  336772  2013      9   30       NaN            2200        NaN
# 336773  336773  2013      9   30       NaN            1210        NaN
# 336774  336774  2013      9   30       NaN            1159        NaN
# 336775  336775  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 336771       NaN            1634        NaN  ...   3393      NaN    JFK  DCA
# 336772       NaN            2312        NaN  ...   3525      NaN    LGA  SYR
# 336773       NaN            1330        NaN  ...   3461   N535MQ    LGA  BNA
# 336774       NaN            1344        NaN  ...   3572   N511MQ    LGA  CLE
# 336775       NaN            1020        NaN  ...   3531   N839MQ    LGA  RDU
#
#        air_time  distance  hour  minute            time_hour  \
# ...

# %%
df.describe()
# Out:
#                   id      year          month            day       dep_time  \
# count  336776.000000  336776.0  336776.000000  336776.000000  328521.000000
# mean   168387.500000    2013.0       6.548510      15.710787    1349.109947
# std     97219.001466       0.0       3.414457       8.768607     488.281791
# min         0.000000    2013.0       1.000000       1.000000       1.000000
# 25%     84193.750000    2013.0       4.000000       8.000000     907.000000
# 50%    168387.500000    2013.0       7.000000      16.000000    1401.000000
# 75%    252581.250000    2013.0      10.000000      23.000000    1744.000000
# max    336775.000000    2013.0      12.000000      31.000000    2400.000000
#
#        sched_dep_time      dep_delay       arr_time  sched_arr_time  \
# count   336776.000000  328521.000000  328063.000000   336776.000000
# mean      1344.254840      12.639070    1502.054999     1536.380220
# std        467.335756      40.210061     533.264132      497.457142
# ...

# %%
df.isnull().any()
# Out:
# id                False
# year              False
# month             False
# day               False
# dep_time           True
# sched_dep_time    False
# dep_delay          True
# arr_time           True
# sched_arr_time    False
# arr_delay          True
# carrier           False
# flight            False
# tailnum            True
# origin            False
# dest              False
# air_time           True
# distance          False
# hour              False
# minute            False
# time_hour         False
# name              False
# dtype: bool

# %% [markdown]
# <p style="background-color:#4B0082;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">📊 EDA</p>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr() , annot=True);

# %%
# انتخاب ستون‌های اعشاری
float_df = df.select_dtypes(include='float')

# انتخاب ستون‌های عدد صحیح
int_df = df.select_dtypes(include='int')

# ادغام دو دیتافریم با هم
num_df = pd.concat([int_df, float_df], axis=1)

# %%
# محاسبه مقادیر آماری داده‌ها
from tabulate import tabulate

summary_df = pd.DataFrame(columns=["Column", "Mean", "Median", "Standard Deviation", "Variance", "Trimmed Mean", "Skewness", "Kurtosis", "Mode", "Correlation"])

for col in num_df.columns:
    mean = num_df[col].mean()
    median = num_df[col].median()
    std = num_df[col].std()
    var = num_df[col].var()
    trim_min = num_df[col].quantile(0.1)
    trim_max = num_df[col].quantile(0.9)
    trimmed_mean = num_df[col][(num_df[col] >= trim_min) & (num_df[col] <= trim_max)].mean()
    skew = num_df[col].skew()
    kurt = num_df[col].kurtosis()
    mode = num_df[col].mode().values[0]
    corr = num_df.corr()[col].to_list()[:-1] # رابطه بین دو ستون برای ستون فعلی
    summary_df = pd.concat([summary_df, pd.DataFrame({
        "Column": [col],
        "Mean": [mean],
        "Median": [median],
        "Standard Deviation": [std],
        "Variance": [var],
        "Trimmed Mean": [trimmed_mean],
        "Skewness": [skew],
        "Kurtosis": [kurt],
        "Mode": [mode],
        "Correlation": [corr]
    })], ignore_index=True)

# تبدیل مقادیر به جدول زیبا
table = tabulate(summary_df, headers="keys", tablefmt="fancy_grid")

# چاپ جدول
print(table)
# Out:
# ╒════╤════════════════╤══════════════╤══════════╤══════════════════════╤══════════════════╤════════════════╤══════════════╤════════════╤════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │    │ Column         │         Mean │   Median │   Standard Deviation │         Variance │   Trimmed Mean │     Skewness │   Kurtosis │   Mode │ Correlation                                                                                                                                                                                                                                                                                         │
# ...

# %%
# # رسم نمودار هیستوگرام برای تمام ستون‌های عددی با استفاده از حلقه
# for col in num_df.columns:
#     plt.hist(num_df[col], bins=200)
#     plt.title(col)
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')
#     plt.show()

# %%
fig = plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)
plt.suptitle("Daily closing prices", fontsize=18, y=0.95)

# حلقه برای رسم نمودارهای هیستوگرام برای هر ستون عددی در دیتافریم
for n, col in enumerate(num_df.columns):
    # افزودن محور جدید به صورت تدریجی
    ax = plt.subplot(5, 3, n + 1)

    # رسم نمودار هیستوگرام برای ستون با تعداد بازه‌های ۲۰۰
    plt.hist(num_df[col], bins=200)

    # تنظیمات نمودار
    ax.set_title(col)
    ax.set_xlabel("Value")
    ax.set_ylabel("Frequency")

plt.show()
fig.savefig("output.png")

# %%
def draw_barplot(_style, _x,_y,_dataset,_suptitle,_xLabels,_yLabels):        
            sns.set(style=_style)         
            g = sns.catplot(x=_x, y=_y, data=_dataset,aspect=2,
                            height=5, kind="bar", palette="muted")
            plt.subplots_adjust(top=0.9)
            g.fig.suptitle(_suptitle)
            g.set_xlabels(_xLabels)
            g.set_ylabels(_yLabels)

# %%
def plot_CountPlot(X,Dataframe,Title):
    fig = plt.figure(figsize=(15,5))
    ax = sns.countplot(x=X, data=Dataframe ,palette='pastel' ,edgecolor=sns.color_palette("dark", 3))
    ax.set_title(Title)
    ax.legend(loc='upper right')

    for t in ax.patches:
        if (np.isnan(float(t.get_height()))):
            ax.annotate(0, (t.get_x(), 0))
        else:
            ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))
    plt.show();

# %%
dt=df.groupby(by='origin').count().reset_index().sort_values(by='year', ascending=False)
dt['flightsCount']=dt.year

#Call Function to draw Bar Graph
draw_barplot(_style='whitegrid',_x='origin',_y='flightsCount',_xLabels='Airport',
             _yLabels='Number of Flights', _dataset=dt,
             _suptitle="Number of Flights from different Airports"
            )

# %%
plot_CountPlot('origin',df,'Number of Flights from different Airports')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot()
# Out:
# /Users/arezaie/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='dep_delay'>
